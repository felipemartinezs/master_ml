# %%
# Example of loading Pima Indians CSV dataset
from csv import reader

# Load a CSV file
def load_csv(filename):
    file = open(filename, "r")
    lines = reader(file)
    dataset = list(lines)
    return dataset

# Load dataset
filename = 'pima-indians-diabetes.csv'
dataset = load_csv(filename)
print('Loaded data file {0} with {1} rows and {2} columns'.format(filename, len(dataset), len(dataset[0])))
# Out:
# Loaded data file pima-indians-diabetes.csv with 768 rows and 9 columns

# %%
dataset
# Out:
# [['6', '148', '72', '35', '0', '33.6', '0.627', '50', '1'],
#  ['1', '85', '66', '29', '0', '26.6', '0.351', '31', '0'],
#  ['8', '183', '64', '0', '0', '23.3', '0.672', '32', '1'],
#  ['1', '89', '66', '23', '94', '28.1', '0.167', '21', '0'],
#  ['0', '137', '40', '35', '168', '43.1', '2.288', '33', '1'],
#  ['5', '116', '74', '0', '0', '25.6', '0.201', '30', '0'],
#  ['3', '78', '50', '32', '88', '31.0', '0.248', '26', '1'],
#  ['10', '115', '0', '0', '0', '35.3', '0.134', '29', '0'],
#  ['2', '197', '70', '45', '543', '30.5', '0.158', '53', '1'],
#  ['8', '125', '96', '0', '0', '0.0', '0.232', '54', '1'],
#  ['4', '110', '92', '0', '0', '37.6', '0.191', '30', '0'],
#  ['10', '168', '74', '0', '0', '38.0', '0.537', '34', '1'],
#  ['10', '139', '80', '0', '0', '27.1', '1.441', '57', '0'],
#  ['1', '189', '60', '23', '846', '30.1', '0.398', '59', '1'],
#  ['5', '166', '72', '19', '175', '25.8', '0.587', '51', '1'],
#  ['7', '100', '0', '0', '0', '30.0', '0.484', '32', '1'],
# ...

# %%
# Example of loading Pima Indians CSV dataset
from csv import reader

# Load a CSV file
def load_csv(filename):
    file = open(filename, "r")
    lines = reader(file)
    dataset = list(lines)
    return dataset

# Load dataset
filename = 'Absenteeism_at_work.csv'
dataset_2 = load_csv(filename)
print('Loaded data file {0} with {1} rows and {2} columns'.format(filename, len(dataset_2), len(dataset_2[0])))
# Out:
# Loaded data file Absenteeism_at_work.csv with 741 rows and 15 columns

# %%
dataset_2
# Out:
# [['ID',
#   'Reason for absence',
#   'Month of absence',
#   'Day of the week',
#   'Seasons',
#   'Transportation expense',
#   'Distance from Residence to Work',
#   'Service time',
#   'Age',
#   'Work load Average/day ',
#   'Hit target',
#   'Disciplinary failure',
#   'Education',
#   'Body mass index',
#   'Absenteeism time in hours'],
#  ['11',
#   '26',
#   '7',
#   '3',
#   '1',
#   '289',
#   '36',
#   '13',
#   '33',
#   '239.554',
#   '97',
#   '0',
#   '1',
#   '30',
#   '4'],
#  ['36',
#   '0',
#   '7',
#   '3',
#   '1',
#   '118',
#   '13',
#   '18',
#   '50',
#   '239.554',
#   '97',
#   '1',
#   '1',
#   '31',
#   '0'],
#  ['3',
#   '23',
#   '7',
#   '4',
#   '1',
#   '179',
#   '51',
#   '18',
#   '38',
#   '239.554',
#   '97',
#   '0',
#   '1',
#   '31',
#   '2'],
#  ['7',
#   '7',
#   '7',
#   '5',
#   '1',
#   '279',
#   '5',
#   '14',
#   '39',
#   '239.554',
#   '97',
#   '0',
#   '1',
#   '24',
#   '4'],
#  ['11',
#   '23',
#   '7',
#   '5',
#   '1',
# ...

# %%
import pandas as pd
df_2 = pd.read_csv('Absenteeism_at_work.csv')
df_2.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  \
# ...

# %%
df_2.shape
# Out:
# (740, 15)

# %%
# Example of loading Pima Indians CSV dataset
from csv import reader

# Load a CSV file
def load_csv(filename):
    file = open(filename, "r")
    lines = reader(file)
    dataset = list(lines)
    return dataset

# Load dataset
filename = 'WA_Fn-UseC_-HR-Employee-Attrition.csv'
dataset_3 = load_csv(filename)
print('Loaded data file {0} with {1} rows and {2} columns'.format(filename, len(dataset_3), len(dataset_3[0])))
# Out:
# Loaded data file WA_Fn-UseC_-HR-Employee-Attrition.csv with 1471 rows and 35 columns

# %%
dataset_3
# Out:
# [['\ufeffAge',
#   'Attrition',
#   'BusinessTravel',
#   'DailyRate',
#   'Department',
#   'DistanceFromHome',
#   'Education',
#   'EducationField',
#   'EmployeeCount',
#   'EmployeeNumber',
#   'EnvironmentSatisfaction',
#   'Gender',
#   'HourlyRate',
#   'JobInvolvement',
#   'JobLevel',
#   'JobRole',
#   'JobSatisfaction',
#   'MaritalStatus',
#   'MonthlyIncome',
#   'MonthlyRate',
#   'NumCompaniesWorked',
#   'Over18',
#   'OverTime',
#   'PercentSalaryHike',
#   'PerformanceRating',
#   'RelationshipSatisfaction',
#   'StandardHours',
#   'StockOptionLevel',
#   'TotalWorkingYears',
#   'TrainingTimesLastYear',
#   'WorkLifeBalance',
#   'YearsAtCompany',
#   'YearsInCurrentRole',
#   'YearsSinceLastPromotion',
#   'YearsWithCurrManager'],
#  ['41',
#   'Yes',
#   'Travel_Rarely',
#   '1102',
#   'Sales',
#   '1',
#   '2',
#   'Life Sciences',
#   '1',
#   '1',
#   '2',
#   'Female',
#   '94',
#   '3',
#   '2',
#   'Sales Executive',
#   '4',
#   'Single',
#   '5993',
# ...

# %%
df_3 = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df_3.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
df_3.shape
# Out:
# (1470, 35)
